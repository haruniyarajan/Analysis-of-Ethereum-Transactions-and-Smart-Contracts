# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Read data from text file
with open("avg_gasused.txt", "r") as f:
    data = f.read()

# Clean up data and split into list of lists
data = data.replace("[[", "").replace("]]", "").replace("], [", "|")
data = data.split("|")
data = [d.split(", ") for d in data]

# Create DataFrame from list of lists
df = pd.DataFrame(data, columns=["Month/Year", "Average_gas_used"])

# Convert Average_gas_used column to float type
df['Average_gas_used'] = df['Average_gas_used'].astype('float')

#Convert the Month/Year column to datetime datatype and sorting them in ascending order.

df['Month/Year']=df['Month/Year'].apply(lambda x: x.strip('"'))
df['Month/Year'] = pd.to_datetime(df['Month/Year'], format='%m/%Y')
df = df.sort_values(by='Month/Year')
# Print the DataFrame
df
# Out:
#    Month/Year  Average_gas_used
# 22 2015-08-01      3.647744e+05
# 26 2015-09-01      6.074794e+05
# 30 2015-10-01      1.064342e+06
# 34 2015-11-01      5.526641e+05
# 38 2015-12-01      4.459484e+05
# 0  2016-01-01      3.586068e+05
# 4  2016-02-01      3.045242e+05
# 7  2016-03-01      2.338062e+05
# 10 2016-04-01      4.233925e+05
# 13 2016-05-01      7.227421e+05
# 16 2016-06-01      3.472637e+05
# 19 2016-07-01      1.785566e+05
# 23 2016-08-01      1.032011e+05
# 27 2016-09-01      1.083711e+05
# 31 2016-10-01      1.251956e+05
# 35 2016-11-01      8.480838e+04
# 39 2016-12-01      6.918403e+04
# 1  2017-01-01      5.852797e+04
# 5  2017-02-01      7.997750e+04
# 8  2017-03-01      7.045276e+04
# 11 2017-04-01      8.294525e+04
# 14 2017-05-01      7.678198e+04
# 17 2017-06-01      1.138770e+05
# 20 2017-07-01      1.212993e+05
# 24 2017-08-01      1.263934e+05
# 28 2017-09-01      1.554981e+05
# 32 2017-10-01      1.595380e+05
# 36 2017-11-01      1.649917e+05
# 40 2017-12-01      2.112221e+05
# 2  2018-01-01      2.403662e+05
# 6  2018-02-01      2.997010e+05
# 9  2018-03-01      3.449167e+05
# 12 2018-04-01      4.943388e+05
# 15 2018-05-01      3.614036e+05
# 18 2018-06-01      3.904203e+05
# 21 2018-07-01      3.184577e+05
# 25 2018-08-01      3.710548e+05
# 29 2018-09-01      3.803911e+05
# 33 2018-10-01      2.424229e+05
# 37 2018-11-01      3.139264e+05
# 41 2018-12-01      3.711215e+05
# 3  2019-01-01      2.976076e+05

# %%
plt.figure(figsize = (15,10))
plt.title("Average gas used change over time")
plt.xticks(rotation=90)
plt.plot(df['Month/Year'], df['Average_gas_used'])
plt.xlabel("Year-Month")
plt.ylabel("Average gas used")
plt.savefig("Average_gas_used.png")  
plt.show()
